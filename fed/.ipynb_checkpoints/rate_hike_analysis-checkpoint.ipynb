# %%
# %matplotlib inline
import datetime
import quandl as q
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.plotly as py  
py.sign_in('oldzhangbuythings', 'R8WuAzDWGs-WFHsyJo25')
import plotly.tools as tls   
from plotly.graph_objs import *

# %%
hike_cycle = pd.read_csv('data_cleaned/rate_hike_circles.csv', index_col=0)
recession_cycle = pd.read_csv('data_cleaned/recession_circles.csv', index_col=0)

gdp_us = pd.read_csv('data_cleaned/real_gdp_index.csv', index_col=0)
gdp_us.index = gdp_us.index.to_datetime()
mask = (gdp_us.index >= '1978-01-03')
gdp_us = gdp_us[mask]

fed_rate = pd.read_csv('data_cleaned/effr_cleaned.csv', index_col=0)
fed_rate.index = fed_rate.index.to_datetime()
mask = (fed_rate.index >= '1978-01-03')
fed_rate = fed_rate[mask]

cpi_us = pd.read_csv('data_raw/cpi_rate.csv', index_col=0)
cpi_us.index = cpi_us.index.to_datetime()
mask = (cpi_us.index >= '1978-01-03')
cpi_us = cpi_us[mask]

dx = pd.read_csv('data_raw/dx_f_m.csv', index_col=0)
dx.index = dx.index.to_datetime()
mask = (dx.index >= '1978-01-03')
dx = dx[mask]

gold = pd.read_csv('data_raw/gc_f_m.csv', index_col=0)
gold.index = gold.index.to_datetime()
mask = (gold.index >= '1978-01-03')
gold = gold[mask]

un_rate = pd.read_csv('data_raw/un_rate_us.csv', index_col=0)
un_rate.index = un_rate.index.to_datetime()
mask = (un_rate.index >= '1978-01-03')
un_rate = un_rate[mask]

# %%
y10y2 = pd.read_csv('data_raw/T10Y2Y.csv', index_col=0)
y10y2.index = y10y2.index.to_datetime()
mask = (y10y2.T10Y2Y != '.')
y10y2 = y10y2[mask]
y10y2.T10Y2Y = y10y2.T10Y2Y.astype('float')

# %%
sp500 = q.get('YAHOO/INDEX_GSPC')
mask_1 = (sp500.index >= '1978-01-03')
sp500 = sp500[mask_1]

vix_raw = q.get('YAHOO/INDEX_VIX', collapse='monthly')
dji_raw = q.get('YAHOO/INDEX_DJI')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e73f2deb1feb> in <module>()
# ----> 1 sp500 = q.get('YAHOO/INDEX_GSPC')
#       2 mask_1 = (sp500.index >= '1978-01-03')
#       3 sp500 = sp500[mask_1]
#       4
#       5 vix_raw = q.get('YAHOO/INDEX_VIX', collapse='monthly')
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/quandl/get.pyc in get(dataset, **kwargs)
#      46         if dataset_args['column_index'] is not None:
#      47             kwargs.update({'column_index': dataset_args['column_index']})
# ---> 48         data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#      49     # Array
#      50     elif isinstance(dataset, list):
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/quandl/model/dataset.pyc in data(self, **options)
#      45         updated_options = Util.merge_options('params', params, **options)
#      46         try:
# ---> 47             return Data.all(**updated_options)
#      48         except NotFoundError:
#      49             if handle_not_found_error:
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/quandl/operations/list.pyc in all(cls, **options)
#      12             options['params'] = {}
#      13         path = Util.constructed_path(cls.list_path(), options['params'])
# ---> 14         r = Connection.request('get', path, **options)
#      15         response_data = r.json()
#      16         Util.convert_to_dates(response_data)
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/quandl/connection.pyc in request(cls, http_verb, url, **options)
#      34         abs_url = '%s/%s' % (ApiConfig.api_base, url)
#      35
# ---> 36         return cls.execute_request(http_verb, abs_url, **options)
#      37
#      38     @classmethod
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/quandl/connection.pyc in execute_request(cls, http_verb, url, **options)
#      40         try:
#      41             func = getattr(requests, http_verb)
# ---> 42             response = func(url, **options)
#      43             if response.status_code < 200 or response.status_code >= 300:
#      44                 cls.handle_api_error(response)
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     343         # Trigger any extra validation we need to do.
#     344         try:
# --> 345             self._validate_conn(conn)
#     346         except (SocketTimeout, BaseSSLError) as e:
#     347             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _validate_conn(self, conn)
#     842         # Force connect early to allow us to validate the connection.
#     843         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 844             conn.connect()
#     845
#     846         if not conn.is_verified:
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/packages/urllib3/connection.pyc in connect(self)
#     282     def connect(self):
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#     286         hostname = self.host
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/packages/urllib3/connection.pyc in _new_conn(self)
#     139         try:
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#     143         except SocketTimeout as e:
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/packages/urllib3/util/connection.pyc in create_connection(address, timeout, source_address, socket_options)
#      71             if source_address:
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#      75
#
# /Users/ZHHR/anaconda2/lib/python2.7/socket.pyc in meth(name, self, *args)
#     226
#     227 def meth(name,self,*args):
# --> 228     return getattr(self._sock,name)(*args)
#     229
#     230 for _m in _socketmethods:
#
# KeyboardInterrupt:

# %%
pmi_new_oder = q.get('ISM/MAN_NEWORDERS')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-cdf91d9a0968> in <module>()
# ----> 1 pmi_new_oder = q.get('ISM/MAN_NEWORDERS')
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/quandl/get.pyc in get(dataset, **kwargs)
#      46         if dataset_args['column_index'] is not None:
#      47             kwargs.update({'column_index': dataset_args['column_index']})
# ---> 48         data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#      49     # Array
#      50     elif isinstance(dataset, list):
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/quandl/model/dataset.pyc in data(self, **options)
#      45         updated_options = Util.merge_options('params', params, **options)
#      46         try:
# ---> 47             return Data.all(**updated_options)
#      48         except NotFoundError:
#      49             if handle_not_found_error:
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/quandl/operations/list.pyc in all(cls, **options)
#      12             options['params'] = {}
#      13         path = Util.constructed_path(cls.list_path(), options['params'])
# ---> 14         r = Connection.request('get', path, **options)
#      15         response_data = r.json()
#      16         Util.convert_to_dates(response_data)
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/quandl/connection.pyc in request(cls, http_verb, url, **options)
#      34         abs_url = '%s/%s' % (ApiConfig.api_base, url)
#      35
# ---> 36         return cls.execute_request(http_verb, abs_url, **options)
#      37
#      38     @classmethod
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/quandl/connection.pyc in execute_request(cls, http_verb, url, **options)
#      40         try:
#      41             func = getattr(requests, http_verb)
# ---> 42             response = func(url, **options)
#      43             if response.status_code < 200 or response.status_code >= 300:
#      44                 cls.handle_api_error(response)
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     343         # Trigger any extra validation we need to do.
#     344         try:
# --> 345             self._validate_conn(conn)
#     346         except (SocketTimeout, BaseSSLError) as e:
#     347             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _validate_conn(self, conn)
#     842         # Force connect early to allow us to validate the connection.
#     843         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 844             conn.connect()
#     845
#     846         if not conn.is_verified:
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/packages/urllib3/connection.pyc in connect(self)
#     282     def connect(self):
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#     286         hostname = self.host
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/packages/urllib3/connection.pyc in _new_conn(self)
#     139         try:
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#     143         except SocketTimeout as e:
#
# /Users/ZHHR/anaconda2/lib/python2.7/site-packages/requests/packages/urllib3/util/connection.pyc in create_connection(address, timeout, source_address, socket_options)
#      71             if source_address:
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#      75
#
# /Users/ZHHR/anaconda2/lib/python2.7/socket.pyc in meth(name, self, *args)
#     226
#     227 def meth(name,self,*args):
# --> 228     return getattr(self._sock,name)(*args)
#     229
#     230 for _m in _socketmethods:
#
# KeyboardInterrupt:

# %%
tcu = pd.read_csv('data_raw/TCU_rate.csv', index_col=0)
tcu.index = tcu.index.to_datetime()
pmi = q.get('ISM/MAN_PMI')

# %%
tcu.iloc[0]
# Out:
# TCU_PCH   -1.566
# Name: 1967-02-01 00:00:00, dtype: float64

# %%
fig, ax1 = plt.subplots()
fig.set_size_inches(16, 8)
#ax1.plot(fed_rate.index, fed_rate.FEDFUNDS)
ax1.plot(tcu.index, tcu.TCU_PCH)
ax1.set_xlim([datetime.date(2006, 1, 26), datetime.date(2017, 4, 1)])

plt.xlim([2000,2017])
plt.xlabel('year')
plt.ylabel('Fed Rate')
for i in xrange(6):
    #ax1.axvspan(hike_cycle.iloc[i, 0], hike_cycle.iloc[i, 1], alpha=0.3, color='red')
    if i < 5:
        ax1.axvspan(recession_cycle.iloc[i, 0], recession_cycle.iloc[i, 1], alpha=0.1, color='grey')
ax2 = ax1.twinx()
#ax2.plot(sp500.index, sp500['Adjusted Close'], 'r')
#ax2.plot(dji.index, dji['Adjusted Close'], 'r')    
#ax2.plot(vix.index, vix['Adjusted Close'], 'r')
#ax2.plot(dx.index, dx['Close'], 'r')
#ax2.plot(gold.index, gold['Close'], 'r')
#ax2.plot(un_rate.index, un_rate['UNRATE'], 'r')
ax2.plot(pmi.index, pmi['Index'], 'r')
ax2.set_xlim([datetime.date(2006, 1, 26), datetime.date(2017, 4, 1)])
plt.plot((pmi.index[0], pmi.index[-1]), (50, 50), 'k-')
#ax2.plot(un_rate.index, un_rate['UNRATE'], 'r')
#ax2.plot(y10y2.index, y10y2['T10Y2Y'], 'r')

#ax2.plot(gdp_plot.DATE, gdp_plot.GDP, 'r')    
#py.iplot_mpl(fig, filename='fed_rates_hike')

# %%
gdp_rate = pd.read_csv('data_raw/gdp_real_rate.csv', index_col=0)
gdp_rate.index = gdp_rate.index.to_datetime()
mask = (gdp_rate.index >= '1998-01-03')
gdp_rate = gdp_rate[mask]

# %%
pce = pd.read_csv('data_raw/pce_rate.csv', index_col=0)
pce.index = pce.index.to_datetime()
mask = (pce.index >= '1998-01-03')
pce = pce[mask]

# %%
tcu = pd.read_csv('data_raw/TCU_rate.csv', index_col=0)
tcu.index = tcu.index.to_datetime()
mask = (tcu.index >= '1998-01-03')
tcu = tcu[mask]

# %%
fig, ax1 = plt.subplots()
fig.set_size_inches(16, 8)
ax1.plot(pce.index, pce.iloc[:, 0])

#ax1.plot(gdp_rate.index, gdp_rate.iloc[:, 0])
plt.xlabel('year')
plt.ylabel('Fed Rate')
#for i in xrange(6):
    #ax1.axvspan(hike_cycle.iloc[i, 0], hike_cycle.iloc[i, 1], alpha=0.3, color='red')
#    if i < 5:
#        ax1.axvspan(recession_cycle.iloc[i, 0], recession_cycle.iloc[i, 1], alpha=0.1, color='grey')
ax2 = ax1.twinx()
ax2.plot(tcu.index, tcu.iloc[:, 0], 'r')
#ax2.plot(dji.index, dji['Adjusted Close'], 'r')    
#ax2.plot(vix.index, vix['Adjusted Close'], 'r')
#ax2.plot(dx.index, dx['Close'], 'r')
#ax2.plot(gold.index, gold['Close'], 'r')
#ax2.plot(un_rate.index, un_rate['UNRATE'], 'r')
#ax2.plot(un_rate.index, un_rate['UNRATE'], 'r')
#ax2.plot(y10y2.index, y10y2['T10Y2Y'], 'r')

#ax2.plot(gdp_plot.DATE, gdp_plot.GDP, 'r')    
#py.iplot_mpl(fig, filename='fed_rates_hike')
